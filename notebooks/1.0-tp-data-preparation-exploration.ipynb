# %%
import sys

sys.path.append('../venv/lib/python3.8/site-packages')

# %% [markdown]
# # Extracing obligations and powers from word document

# %%
from docx2python import docx2python as d2p

# %%
doc = d2p('../data/contracts/DPA - Annotated.docx')
doc.body
# Out:
# [[[['Annotation on Smart Contracts',
#     '',
#     '',
#     'Procedure followed in the annotation',
#     '',
#     'Please consider the clause(s) below from the Data Processing Addendum signed between Atos (as Processor of data) and a Client (as Controller). In relation to each of the different paragraphs or sections of the clause, answer the following question:',
#     '',
#     '--\tDoes it make sense, considering both a business, legal and a technical perspective, to convert this clause into a ‘smart’ clause?\xa0',
#     '',
#     '( ) NO  Highlight this section/paragraph in RED. Below it, explain why it would not be pertinent to convert it into a smart clause (considering both business, legal  and technical considerations).',
#     '',
#     '',
# ...

# %%
doc.body[0][0][0][0]
# Out:
# 'Annotation on Smart Contracts'

# %%
doc.body[2]
# Out:
# [[['']]]
